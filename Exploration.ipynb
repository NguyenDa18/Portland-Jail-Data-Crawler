# %%
import pandas as pd
import json

# %%
CSV_URL = "https://raw.githubusercontent.com/NguyenDa18/Portland-Jail-Data-Crawler/main/csvs/inmate_details.csv"

df = pd.read_csv(CSV_URL)

# %%
df
# Out:
#      SWIS ID                       Name  Age Gender   Race      Height  \
# 0     821247           Barrett, Patrick   34   Male  Black   5 ft 8 in
# 1     655352  Nirschl, John Josephalber   43   Male  White  5 ft 11 in
# 2     810789       Porter, Greg Phillip   65   Male  White   5 ft 6 in
# 3     761726       Mccool, Joel Matthew   31   Male  Black   5 ft 7 in
# 4      86303       Garner, Brandon Paul   54   Male  Black   6 ft 1 in
# ..       ...                        ...  ...    ...    ...         ...
# 833    99882          Malaterre, Alan P   62   Male  White   6 ft 4 in
# 834   825878     Idebi, Anthony Abayomi   34   Male  Black  5 ft 10 in
# 835   130828        Hudson, Dustin Ryan   46   Male  White   5 ft 7 in
# 836     3866        Handy, Anthony Leon   62   Male  Black  5 ft 10 in
# 837   806416                Davis, Eric   58   Male  Black  5 ft 11 in
#
#       Weight   Hair   Eyes                   Arresting Agency  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SWIS ID                 838 non-null    int64
#  1   Name                    838 non-null    object
#  2   Age                     838 non-null    int64
#  3   Gender                  838 non-null    object
#  4   Race                    838 non-null    object
#  5   Height                  838 non-null    object
#  6   Weight                  838 non-null    object
#  7   Hair                    838 non-null    object
#  8   Eyes                    838 non-null    object
#  9   Arresting Agency        833 non-null    object
#  10  Booking Date            838 non-null    object
#  11  Assigned Facility       838 non-null    object
#  12  Projected Release Date  838 non-null    object
#  13  Charge Type Counts      838 non-null    object
# ...

# %%
charges = pd.DataFrame(df['Charge Type Counts'])
charges
# Out:
#                                     Charge Type Counts
# 0               {'ASSAULT IV - DV (A Misdemeanor)': 1}
# 1                          {'USM HOLD (U Unknown)': 1}
# 2    {'ATT AGGR MURDER (A Felony)': 6, 'ASSAULT I (...
# 3    {'UNLAW USE WEAPON (C Felony)': 19, 'ATT AGGR ...
# 4    {'PROM PROST (C Felony)': 3, 'COMPELL PROST (B...
# ..                                                 ...
# 833  {'DUII - MISD (A Misdemeanor)': 1, 'COUNTY HOL...
# 834                     {'COUNTY HOLD (U Unknown)': 2}
# 835              {'PAROLE OR PPSV VIOL (U Felony)': 1}
# 836  {'ASSAULT IV - DV (A Misdemeanor)': 3, 'UNLAW ...
# 837  {'ATT ELUDE BY VEHCLE (C Felony)': 1, 'CARRY C...
#
# [838 rows x 1 columns]

# %%
type(charges.iloc[0]['Charge Type Counts'])
# Out:
# str

# %%
df.iloc[0]
# Out:
# SWIS ID                                                              827491
# Name                                                    Damron, John Thomas
# Age                                                                      35
# Gender                                                                 Male
# Race                                                                  White
# Height                                                            5 ft 9 in
# Weight                                                              180 lbs
# Hair                                                                  Brown
# Eyes                                                                  Hazel
# Arresting Agency                                     Portland Police, Other
# Booking Date                                            03/17/2021 08:15 PM
# Assigned Facility                                                      MCIJ
# ...

# %%
import json

df.iloc[-1]['Charges']
# Out:
# "[{'Type': 'UUMV (C Felony)', 'Bail': '$0', 'Status': 'Sentenced'}]"
